# %%
import pyreadr
import pandas as pd

# %%
result = pyreadr.read_r("/data/IDEA_DeFi_Research/Data/Lending_Protocols/Aave/V2/Mainnet/transactions.rds")

# %%
df = result[None] # extract the pandas data frame

# %%
pd.set_option('mode.chained_assignment', None)

# %%
df
# Out:
#                                                         id       type  \
# 0        0xc70f4c3f447f6a88e9fbb87ac1394b589e469ee57dda...     borrow
# 1        0x1ee3db904548c16d2ed3572f3d9894652e031facc8fa...     borrow
# 2        0x1e8f85330edc5005ead7a7ae8c418fbb64df726d4ffc...     borrow
# 3        0x43136c7aba13c072bb19ed88f8eadf859f0bfb994b42...     borrow
# 4        0xd96af0cf05a1e99125fe51ee7e27a1c96cf40ea6e596...     borrow
# ...                                                    ...        ...
# 1997861  0x8cad9046690a28e3d7511703ee2d5260a4ac4cb9fade...  flashLoan
# 1997862  0x0867140ba5fe5323b2ef34118bb1192394e75011c7de...  flashLoan
# 1997863  0xd6d70c6a071d059a1607acd512bce4ce655ee23d61e5...  flashLoan
# 1997864  0x4a53b2336aff19ba21a9174664711e6a0d39b8738e51...  flashLoan
# 1997865  0x2243b39568005d7aa49384ccdd58ffeb11e84a5274f5...  flashLoan
#
#             timestamp                                        user  \
# 0        1.606841e+09  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 1        1.606902e+09  0x21d05071ca08593e13cd3afd0b4869537e015c92
# 2        1.606905e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 3        1.606913e+09  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 4        1.606915e+09  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
# ...               ...                                         ...
# 1997861  1.710852e+09                                         NaN
# 1997862  1.710856e+09                                         NaN
# 1997863  1.710860e+09                                         NaN
# 1997864  1.710860e+09                                         NaN
# 1997865  1.710865e+09                                         NaN
#
#                      userAlias                                  onBehalfOf  \
# 0           Asia Marie Waldron  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 1        Scott Volentir-Herman  0x21d05071ca08593e13cd3afd0b4869537e015c92
# 2               Jacob Banister  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 3               Jacob Banister  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 4                Jerry Serrano  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
# ...                        ...                                         ...
# 1997861                    NaN                                         NaN
# 1997862                    NaN                                         NaN
# 1997863                    NaN                                         NaN
# 1997864                    NaN                                         NaN
# 1997865                    NaN                                         NaN
#
#                onBehalfOfAlias                                        pool  \
# 0           Asia Marie Waldron  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1        Scott Volentir-Herman  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 2               Jacob Banister  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 3               Jacob Banister  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 4                Jerry Serrano  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# ...                        ...                                         ...
# 1997861                    NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1997862                    NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1997863                    NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1997864                    NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1997865                    NaN  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
#
#         reserve        amount  ...  liquidatorAlias  priceInUsd  \
# 0           DAI  1.000000e+00  ...              NaN         NaN
# 1           DAI  1.000000e+00  ...              NaN         NaN
# 2          LINK  1.000000e+00  ...              NaN         NaN
# 3          AAVE  5.000000e-02  ...              NaN         NaN
# 4           DAI  1.000000e+00  ...              NaN         NaN
# ...         ...           ...  ...              ...         ...
# 1997861     PAX  3.106375e+22  ...              NaN         NaN
# 1997862    WETH  1.237885e+18  ...              NaN         NaN
# 1997863    WETH  2.577000e+19  ...              NaN         NaN
# 1997864    WBTC  2.000000e+08  ...              NaN         NaN
# 1997865    WETH  3.498147e+19  ...              NaN         NaN
#
#          borrowRateModeTo borrowRateModeFrom stableBorrowRate  \
# 0                     NaN                NaN              NaN
# 1                     NaN                NaN              NaN
# 2                     NaN                NaN              NaN
# 3                     NaN                NaN              NaN
# 4                     NaN                NaN              NaN
# ...                   ...                ...              ...
# 1997861               NaN                NaN              NaN
# 1997862               NaN                NaN              NaN
# 1997863               NaN                NaN              NaN
# 1997864               NaN                NaN              NaN
# 1997865               NaN                NaN              NaN
#
#         variableBorrowRate                                      target  \
# 0                      NaN                                         NaN
# 1                      NaN                                         NaN
# 2                      NaN                                         NaN
# 3                      NaN                                         NaN
# 4                      NaN                                         NaN
# ...                    ...                                         ...
# 1997861                NaN  0x6a6fa664d4fa49a6a780a1d6143f079f8dd7c33d
# 1997862                NaN  0x80aca0c645fedabaa20fd2bf0daf57885a309fe6
# 1997863                NaN  0x135896de8421be2ec868e0b811006171d9df802a
# 1997864                NaN  0x135896de8421be2ec868e0b811006171d9df802a
# 1997865                NaN  0x95c9ee5c9dbfc187743aff7af0f647821e95066d
#
#              totalFee version  deployment
# 0                 NaN      V2     Mainnet
# 1                 NaN      V2     Mainnet
# 2                 NaN      V2     Mainnet
# 3                 NaN      V2     Mainnet
# 4                 NaN      V2     Mainnet
# ...               ...     ...         ...
# 1997861  2.795737e+19      V2     Mainnet
# 1997862  1.114097e+15      V2     Mainnet
# 1997863  2.319300e+16      V2     Mainnet
# 1997864  1.800000e+05      V2     Mainnet
# 1997865  3.148332e+16      V2     Mainnet
#
# [1997866 rows x 35 columns]

# %%
# %store df
# Out:
# Stored 'df' (DataFrame)

# %%
df.isna()
# Out:
#             id   type  timestamp   user  userAlias  onBehalfOf  \
# 0        False  False      False  False      False       False
# 1        False  False      False  False      False       False
# 2        False  False      False  False      False       False
# 3        False  False      False  False      False       False
# 4        False  False      False  False      False       False
# ...        ...    ...        ...    ...        ...         ...
# 1997861  False  False      False   True       True        True
# 1997862  False  False      False   True       True        True
# 1997863  False  False      False   True       True        True
# 1997864  False  False      False   True       True        True
# 1997865  False  False      False   True       True        True
#
#          onBehalfOfAlias   pool  reserve  amount  ...  liquidatorAlias  \
# 0                  False  False    False   False  ...             True
# 1                  False  False    False   False  ...             True
# 2                  False  False    False   False  ...             True
# 3                  False  False    False   False  ...             True
# 4                  False  False    False   False  ...             True
# ...                  ...    ...      ...     ...  ...              ...
# 1997861             True  False    False   False  ...             True
# 1997862             True  False    False   False  ...             True
# 1997863             True  False    False   False  ...             True
# 1997864             True  False    False   False  ...             True
# 1997865             True  False    False   False  ...             True
#
#          priceInUsd  borrowRateModeTo  borrowRateModeFrom  stableBorrowRate  \
# 0              True              True                True              True
# 1              True              True                True              True
# 2              True              True                True              True
# 3              True              True                True              True
# 4              True              True                True              True
# ...             ...               ...                 ...               ...
# 1997861        True              True                True              True
# 1997862        True              True                True              True
# 1997863        True              True                True              True
# 1997864        True              True                True              True
# 1997865        True              True                True              True
#
#          variableBorrowRate  target  totalFee  version  deployment
# 0                      True    True      True    False       False
# 1                      True    True      True    False       False
# 2                      True    True      True    False       False
# 3                      True    True      True    False       False
# 4                      True    True      True    False       False
# ...                     ...     ...       ...      ...         ...
# 1997861                True   False     False    False       False
# 1997862                True   False     False    False       False
# 1997863                True   False     False    False       False
# 1997864                True   False     False    False       False
# 1997865                True   False     False    False       False
#
# [1997866 rows x 35 columns]

# %%
df.isnull().sum()
# Out:
# id                           0
# type                         0
# timestamp                    0
# user                     43541
# userAlias                43541
# onBehalfOf              703524
# onBehalfOfAlias         703524
# pool                         0
# reserve                  29413
# amount                  659983
# amountUSD               703524
# amountETH               703524
# borrowRate             1740348
# borrowRateMode         1740348
# fromState              1371169
# toState                1371169
# liquidator             1968453
# principalAmount        1968570
# principalReserve       1968570
# principalAmountUSD     1968570
# principalAmountETH     1968570
# collateralAmount       1968568
# collateralReserve      1968568
# collateralAmountUSD    1968568
# collateralAmountETH    1968568
# liquidatorAlias        1968453
# priceInUsd             1440289
# borrowRateModeTo       1993993
# borrowRateModeFrom     1993993
# stableBorrowRate       1993993
# variableBorrowRate     1993993
# target                 1954325
# totalFee               1954325
# version                      0
# deployment                   0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
missing_matrix = df.isnull()
plt.figure(figsize=(20, 10))
missing_heat_map = sns.heatmap(data = missing_matrix)
missing_heat_map.set(xlabel = 'Features')
missing_heat_map.set(ylabel = 'Samples')
plt.title('Missingness Heatmap')
plt.show()

# %%
corr = df.corr() 
sns.heatmap(corr, annot=True, ax=plt.subplots(figsize=(20,10))[1]) 
plt.title('Correlation Heatmap') 
plt.show()

# %%
df.head()
# Out:
#                                                   id    type     timestamp  \
# 0  0xc70f4c3f447f6a88e9fbb87ac1394b589e469ee57dda...  borrow  1.606841e+09
# 1  0x1ee3db904548c16d2ed3572f3d9894652e031facc8fa...  borrow  1.606902e+09
# 2  0x1e8f85330edc5005ead7a7ae8c418fbb64df726d4ffc...  borrow  1.606905e+09
# 3  0x43136c7aba13c072bb19ed88f8eadf859f0bfb994b42...  borrow  1.606913e+09
# 4  0xd96af0cf05a1e99125fe51ee7e27a1c96cf40ea6e596...  borrow  1.606915e+09
#
#                                          user              userAlias  \
# 0  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f     Asia Marie Waldron
# 1  0x21d05071ca08593e13cd3afd0b4869537e015c92  Scott Volentir-Herman
# 2  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c         Jacob Banister
# 3  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c         Jacob Banister
# 4  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1          Jerry Serrano
#
#                                    onBehalfOf        onBehalfOfAlias  \
# 0  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f     Asia Marie Waldron
# 1  0x21d05071ca08593e13cd3afd0b4869537e015c92  Scott Volentir-Herman
# 2  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c         Jacob Banister
# 3  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c         Jacob Banister
# 4  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1          Jerry Serrano
#
#                                          pool reserve  amount  ...  \
# 0  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI    1.00  ...
# 1  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI    1.00  ...
# 2  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    LINK    1.00  ...
# 3  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5    AAVE    0.05  ...
# 4  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5     DAI    1.00  ...
#
#    liquidatorAlias  priceInUsd  borrowRateModeTo borrowRateModeFrom  \
# 0              NaN         NaN               NaN                NaN
# 1              NaN         NaN               NaN                NaN
# 2              NaN         NaN               NaN                NaN
# 3              NaN         NaN               NaN                NaN
# 4              NaN         NaN               NaN                NaN
#
#   stableBorrowRate variableBorrowRate target  totalFee version  deployment
# 0              NaN                NaN    NaN       NaN      V2     Mainnet
# 1              NaN                NaN    NaN       NaN      V2     Mainnet
# 2              NaN                NaN    NaN       NaN      V2     Mainnet
# 3              NaN                NaN    NaN       NaN      V2     Mainnet
# 4              NaN                NaN    NaN       NaN      V2     Mainnet
#
# [5 rows x 35 columns]

# %%
types = df['type'].unique()
print(f'Different types: {types}')
# Out:
# Different types: ['borrow' 'collateral' 'deposit' 'liquidation' 'withdraw' 'repay' 'swap'
#  'flashLoan']

# %%
subframes = [ df[df['type'] == i] for i in types ]

# %%
# %store subframes
# Out:
# Stored 'subframes' (list)

# %%
def clean_data(df):
    return (
        df
         .dropna(axis=1)
         .assign(date=pd.to_datetime(df['timestamp']))
         .set_index('date')
         .drop('id', axis='columns')
         .drop('timestamp', axis='columns')
         .sort_index()
    )

# %%
cleaned = [clean_data(i) for i in subframes]

# %%
# %store cleaned
# Out:
# Stored 'cleaned' (list)

# %%
borrow, collateral, deposit, liquidation, withdraw, repay, swap, flashLoan = cleaned

# %% [markdown]
# Above we stored the individual dataframes of cleaned by the type of transaction, which will allow us to train models on the cleaned data by transaction type more effectively.

# %%
# %store borrow
# %store collateral
# %store deposit
# %store liquidation
# %store withdraw
# %store repay
# %store swap
# %store flashLoan
# Out:
# Stored 'borrow' (DataFrame)
# Stored 'collateral' (DataFrame)
# Stored 'deposit' (DataFrame)
# Stored 'liquidation' (DataFrame)
# Stored 'withdraw' (DataFrame)
# Stored 'repay' (DataFrame)
# Stored 'swap' (DataFrame)
# Stored 'flashLoan' (DataFrame)

# %% [markdown]
# Using the %store magic will allow for these variables to be stored without having to rerun the program when restarting the kernel.

# %%
print(borrow.head())
# Out:
#                                  type  \
# date
# 1970-01-01 00:00:01.606841218  borrow
# 1970-01-01 00:00:01.606901658  borrow
# 1970-01-01 00:00:01.606904690  borrow
# 1970-01-01 00:00:01.606913241  borrow
# 1970-01-01 00:00:01.606914619  borrow
#
#                                                                      user  \
# date
# 1970-01-01 00:00:01.606841218  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 1970-01-01 00:00:01.606901658  0x21d05071ca08593e13cd3afd0b4869537e015c92
# 1970-01-01 00:00:01.606904690  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1970-01-01 00:00:01.606913241  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1970-01-01 00:00:01.606914619  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
#
#                                            userAlias  \
# date
# 1970-01-01 00:00:01.606841218     Asia Marie Waldron
# 1970-01-01 00:00:01.606901658  Scott Volentir-Herman
# 1970-01-01 00:00:01.606904690         Jacob Banister
# 1970-01-01 00:00:01.606913241         Jacob Banister
# 1970-01-01 00:00:01.606914619          Jerry Serrano
#
#                                                                onBehalfOf  \
# date
# 1970-01-01 00:00:01.606841218  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 1970-01-01 00:00:01.606901658  0x21d05071ca08593e13cd3afd0b4869537e015c92
# 1970-01-01 00:00:01.606904690  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1970-01-01 00:00:01.606913241  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1970-01-01 00:00:01.606914619  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
#
#                                      onBehalfOfAlias  \
# date
# 1970-01-01 00:00:01.606841218     Asia Marie Waldron
# 1970-01-01 00:00:01.606901658  Scott Volentir-Herman
# 1970-01-01 00:00:01.606904690         Jacob Banister
# 1970-01-01 00:00:01.606913241         Jacob Banister
# 1970-01-01 00:00:01.606914619          Jerry Serrano
#
#                                                                      pool  \
# date
# 1970-01-01 00:00:01.606841218  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606901658  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606904690  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606913241  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606914619  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
#
#                               reserve  amount  amountUSD  amountETH  \
# date
# 1970-01-01 00:00:01.606841218     DAI    1.00   1.001646   0.002140
# 1970-01-01 00:00:01.606901658     DAI    1.00   1.001646   0.002140
# 1970-01-01 00:00:01.606904690    LINK    1.00  12.761559   0.027269
# 1970-01-01 00:00:01.606913241    AAVE    0.05   3.604718   0.007703
# 1970-01-01 00:00:01.606914619     DAI    1.00   1.001646   0.002140
#
#                                borrowRate borrowRateMode version deployment
# date
# 1970-01-01 00:00:01.606841218    1.250000       Variable      V2    Mainnet
# 1970-01-01 00:00:01.606901658    2.500015       Variable      V2    Mainnet
# 1970-01-01 00:00:01.606904690   67.635468       Variable      V2    Mainnet
# 1970-01-01 00:00:01.606913241    0.000000       Variable      V2    Mainnet
# 1970-01-01 00:00:01.606914619    0.141511       Variable      V2    Mainnet

# %%
corr = borrow.corr()
sns.heatmap(corr, annot=True, ax=plt.subplots(figsize=(20, 10))[1])
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # **Step 1: Building an Existing RNN Model**
#
# Wil use tensorflow and LSTM first.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Load the borrow dataset
# Assuming 'borrow' is the DataFrame containing sequential borrowing data
# If not already loaded, load the DataFrame here

# %%
# Data Preprocessing
# Encode categorical variables
label_encoder = LabelEncoder()
borrow['user'] = label_encoder.fit_transform(borrow['user'])

# %%
# Scale numerical variables
scaler = StandardScaler()
numerical_cols = ['amount', 'amountUSD', 'amountETH']
borrow[numerical_cols] = scaler.fit_transform(borrow[numerical_cols])

# %%
# Organize data into sequences
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# %%
# Define sequence length
seq_length = 10
# Create sequences for training
X = create_sequences(
    borrow[['user', 'amount', 'amountUSD', 'amountETH']].values, seq_length)
y = borrow['amount'].values[seq_length - 1:]

# %%
# Define Training and Validation Sets
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, shuffle=False)

# %%
# Build the RNN Model
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(units=64, input_shape=(
        X_train.shape[1], X_train.shape[2])),
    tf.keras.layers.Dense(units=1)
])

# %%
# Compile the Model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
# Train the Model
history = model.fit(X_train, y_train, epochs=11,
                    batch_size=64, validation_data=(X_val, y_val))
# Out:
# Epoch 1/11
# 3219/3219 [==============================] - 16s 5ms/step - loss: 1.1780 - mae: 0.1433 - val_loss: 0.2765 - val_mae: 0.1420
# Epoch 2/11
# 3219/3219 [==============================] - 16s 5ms/step - loss: 1.1799 - mae: 0.1451 - val_loss: 0.2782 - val_mae: 0.2012
# Epoch 3/11
# 3219/3219 [==============================] - 16s 5ms/step - loss: 1.1792 - mae: 0.1434 - val_loss: 0.2765 - val_mae: 0.1863
# Epoch 4/11
# 3219/3219 [==============================] - 16s 5ms/step - loss: 1.1788 - mae: 0.1432 - val_loss: 0.2755 - val_mae: 0.1625
# Epoch 5/11
# 3219/3219 [==============================] - 16s 5ms/step - loss: 1.1784 - mae: 0.1431 - val_loss: 0.2759 - val_mae: 0.1551
# Epoch 6/11
# 3219/3219 [==============================] - 16s 5ms/step - loss: 1.1788 - mae: 0.1448 - val_loss: 0.2769 - val_mae: 0.1392
# Epoch 7/11
# 3219/3219 [==============================] - 16s 5ms/step - loss: 1.1787 - mae: 0.1453 - val_loss: 0.2776 - val_mae: 0.1977
# Epoch 8/11
# 3219/3219 [==============================] - 16s 5ms/step - loss: 1.1787 - mae: 0.1436 - val_loss: 0.2759 - val_mae: 0.1547
# Epoch 9/11
# 3219/3219 [==============================] - 16s 5ms/step - loss: 1.1795 - mae: 0.1438 - val_loss: 0.2765 - val_mae: 0.1443
# Epoch 10/11
# 3219/3219 [==============================] - 16s 5ms/step - loss: 1.1789 - mae: 0.1425 - val_loss: 0.2755 - val_mae: 0.1652
# Epoch 11/11
# 3219/3219 [==============================] - 16s 5ms/step - loss: 1.1794 - mae: 0.1445 - val_loss: 0.2779 - val_mae: 0.1322

# %%
# Evaluate the Model
mse, mae = model.evaluate(X_val, y_val)
print(f'Validation MSE: {mse}, Validation MAE: {mae}')

# %%
collateral.head()
# Out:
#                                      type  \
# date
# 1970-01-01 00:00:01.606777900  collateral
# 1970-01-01 00:00:01.606836555  collateral
# 1970-01-01 00:00:01.606836949  collateral
# 1970-01-01 00:00:01.606837339  collateral
# 1970-01-01 00:00:01.606837339  collateral
#
#                                                                      user  \
# date
# 1970-01-01 00:00:01.606777900  0xc4a936b003bc223df757b35ee52f6da66b062935
# 1970-01-01 00:00:01.606836555  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
# 1970-01-01 00:00:01.606836949  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
# 1970-01-01 00:00:01.606837339  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
# 1970-01-01 00:00:01.606837339  0xdcd33426ba191383f1c9b431a342498fdac73488
#
#                                       userAlias  \
# date
# 1970-01-01 00:00:01.606777900     Cetan Cackler
# 1970-01-01 00:00:01.606836555     Jerry Serrano
# 1970-01-01 00:00:01.606836949     Jerry Serrano
# 1970-01-01 00:00:01.606837339     Jerry Serrano
# 1970-01-01 00:00:01.606837339  Rashaad el-Amini
#
#                                                                      pool  \
# date
# 1970-01-01 00:00:01.606777900  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606836555  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606836949  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606837339  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606837339  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
#
#                               reserve fromState toState version deployment
# date
# 1970-01-01 00:00:01.606777900    WETH     False    True      V2    Mainnet
# 1970-01-01 00:00:01.606836555    AAVE     False    True      V2    Mainnet
# 1970-01-01 00:00:01.606836949    WETH     False    True      V2    Mainnet
# 1970-01-01 00:00:01.606837339    WETH      True   False      V2    Mainnet
# 1970-01-01 00:00:01.606837339    WETH     False    True      V2    Mainnet

# %%
corrC = collateral.corr()
sns.heatmap(corrC, annot=True, ax=plt.subplots(figsize=(20, 10))[1])
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-6811166a1114> in <module>
#       1 corrC = collateral.corr()
# ----> 2 sns.heatmap(corrC, annot=True, ax=plt.subplots(figsize=(20, 10))[1])
#       3 plt.title('Correlation Heatmap')
#       4 plt.show()
#
# ~/.conda/envs/avilez-py36/lib/python3.6/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/.conda/envs/avilez-py36/lib/python3.6/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 542                           yticklabels, mask)
#     543
#     544     # Add the pcolormesh kwargs here
#
# ~/.conda/envs/avilez-py36/lib/python3.6/site-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     158         # Determine good default values for the colormapping
#     159         self._determine_cmap_params(plot_data, vmin, vmax,
# --> 160                                     cmap, center, robust)
#     161
#     162         # Sort out the annotations
#
# ~/.conda/envs/avilez-py36/lib/python3.6/site-packages/seaborn/matrix.py in _determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     196                 vmin = np.nanpercentile(calc_data, 2)
#     197             else:
# --> 198                 vmin = np.nanmin(calc_data)
#     199         if vmax is None:
#     200             if robust:
#
# <__array_function__ internals> in nanmin(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/nanfunctions.py in nanmin(a, axis, out, keepdims)
#     317         # Fast, but not safe for subclasses of ndarray, or object arrays,
#     318         # which do not implement isnan (gh-9009), or fmin correctly (gh-8975)
# --> 319         res = np.fmin.reduce(a, axis=axis, out=out, **kwargs)
#     320         if np.isnan(res).any():
#     321             warnings.warn("All-NaN slice encountered", RuntimeWarning,
#
# ValueError: zero-size array to reduction operation fmin which has no identity

# %%
deposit.head()
# Out:
#                                   type  \
# date
# 1970-01-01 00:00:01.606777900  deposit
# 1970-01-01 00:00:01.606778006  deposit
# 1970-01-01 00:00:01.606836555  deposit
# 1970-01-01 00:00:01.606836949  deposit
# 1970-01-01 00:00:01.606840248  deposit
#
#                                                                      user  \
# date
# 1970-01-01 00:00:01.606777900  0xc4a936b003bc223df757b35ee52f6da66b062935
# 1970-01-01 00:00:01.606778006  0xc4a936b003bc223df757b35ee52f6da66b062935
# 1970-01-01 00:00:01.606836555  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
# 1970-01-01 00:00:01.606836949  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
# 1970-01-01 00:00:01.606840248  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
#
#                                     userAlias  \
# date
# 1970-01-01 00:00:01.606777900   Kendyl Nipper
# 1970-01-01 00:00:01.606778006   Kendyl Nipper
# 1970-01-01 00:00:01.606836555  Jalen Mitchell
# 1970-01-01 00:00:01.606836949  Jalen Mitchell
# 1970-01-01 00:00:01.606840248   Rocky Kuebler
#
#                                                                onBehalfOf  \
# date
# 1970-01-01 00:00:01.606777900  0xdcd33426ba191383f1c9b431a342498fdac73488
# 1970-01-01 00:00:01.606778006  0xdcd33426ba191383f1c9b431a342498fdac73488
# 1970-01-01 00:00:01.606836555  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
# 1970-01-01 00:00:01.606836949  0xdcd33426ba191383f1c9b431a342498fdac73488
# 1970-01-01 00:00:01.606840248  0xdcd33426ba191383f1c9b431a342498fdac73488
#
#                                    onBehalfOfAlias  \
# date
# 1970-01-01 00:00:01.606777900  Madison Lira-Chacon
# 1970-01-01 00:00:01.606778006  Madison Lira-Chacon
# 1970-01-01 00:00:01.606836555       Jalen Mitchell
# 1970-01-01 00:00:01.606836949  Madison Lira-Chacon
# 1970-01-01 00:00:01.606840248  Madison Lira-Chacon
#
#                                                                      pool  \
# date
# 1970-01-01 00:00:01.606777900  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606778006  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606836555  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606836949  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606840248  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
#
#                               reserve  amount  amountUSD  amountETH version  \
# date
# 1970-01-01 00:00:01.606777900    WETH  0.0001   0.046798   0.000100      V2
# 1970-01-01 00:00:01.606778006    WETH  0.0001   0.046798   0.000100      V2
# 1970-01-01 00:00:01.606836555    AAVE  0.1000   7.209435   0.015405      V2
# 1970-01-01 00:00:01.606836949    WETH  0.0010   0.467980   0.001000      V2
# 1970-01-01 00:00:01.606840248    WETH  0.0010   0.467980   0.001000      V2
#
#                               deployment
# date
# 1970-01-01 00:00:01.606777900    Mainnet
# 1970-01-01 00:00:01.606778006    Mainnet
# 1970-01-01 00:00:01.606836555    Mainnet
# 1970-01-01 00:00:01.606836949    Mainnet
# 1970-01-01 00:00:01.606840248    Mainnet

# %%
corr = deposit.corr()
sns.heatmap(corr, annot=True, ax=plt.subplots(figsize=(20, 10))[1])
plt.title('Correlation Heatmap')
plt.show()

# %%
liquidation.head()
# Out:
#                                       type  \
# date
# 1970-01-01 00:00:01.608214767  liquidation
# 1970-01-01 00:00:01.608214863  liquidation
# 1970-01-01 00:00:01.608214892  liquidation
# 1970-01-01 00:00:01.608215016  liquidation
# 1970-01-01 00:00:01.608218435  liquidation
#
#                                                                      user  \
# date
# 1970-01-01 00:00:01.608214767  0xa53fe221bd861f75907d8fd496db1c70779721aa
# 1970-01-01 00:00:01.608214863  0x9a90affd5fd50561a98a6fb4358f941a131ac592
# 1970-01-01 00:00:01.608214892  0x9a90affd5fd50561a98a6fb4358f941a131ac592
# 1970-01-01 00:00:01.608215016  0xa0b38f17b0ca2536a0e7606fcf01ef13d9b0793c
# 1970-01-01 00:00:01.608218435  0xa53fe221bd861f75907d8fd496db1c70779721aa
#
#                                      userAlias  \
# date
# 1970-01-01 00:00:01.608214767     Karagan Cobb
# 1970-01-01 00:00:01.608214863  Ivaysha Younger
# 1970-01-01 00:00:01.608214892  Ivaysha Younger
# 1970-01-01 00:00:01.608215016     Alec Lizardo
# 1970-01-01 00:00:01.608218435     Karagan Cobb
#
#                                                                      pool  \
# date
# 1970-01-01 00:00:01.608214767  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.608214863  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.608214892  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.608215016  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.608218435  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
#
#                                                                liquidator  \
# date
# 1970-01-01 00:00:01.608214767  0x7a512a3cf68df453ec76d487e3eaffecd74d6887
# 1970-01-01 00:00:01.608214863  0x08b5cabc97b3e4fef88d8f2ccb0442a669e052f8
# 1970-01-01 00:00:01.608214892  0x7a512a3cf68df453ec76d487e3eaffecd74d6887
# 1970-01-01 00:00:01.608215016  0x7a512a3cf68df453ec76d487e3eaffecd74d6887
# 1970-01-01 00:00:01.608218435  0x7a512a3cf68df453ec76d487e3eaffecd74d6887
#
#                               liquidatorAlias version deployment
# date
# 1970-01-01 00:00:01.608214767  Smart Contract      V2    Mainnet
# 1970-01-01 00:00:01.608214863  Smart Contract      V2    Mainnet
# 1970-01-01 00:00:01.608214892  Smart Contract      V2    Mainnet
# 1970-01-01 00:00:01.608215016  Smart Contract      V2    Mainnet
# 1970-01-01 00:00:01.608218435  Smart Contract      V2    Mainnet

# %%
corr = liquidation.corr()
sns.heatmap(corr, annot=True, ax=plt.subplots(figsize=(20, 10))[1])
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-11f4ac10640a> in <module>
#       1 corr = liquidation.corr()
# ----> 2 sns.heatmap(corr, annot=True, ax=plt.subplots(figsize=(20, 10))[1])
#       3 plt.title('Correlation Heatmap')
#       4 plt.show()
#
# ~/.conda/envs/avilez-py36/lib/python3.6/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/.conda/envs/avilez-py36/lib/python3.6/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 542                           yticklabels, mask)
#     543
#     544     # Add the pcolormesh kwargs here
#
# ~/.conda/envs/avilez-py36/lib/python3.6/site-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     158         # Determine good default values for the colormapping
#     159         self._determine_cmap_params(plot_data, vmin, vmax,
# --> 160                                     cmap, center, robust)
#     161
#     162         # Sort out the annotations
#
# ~/.conda/envs/avilez-py36/lib/python3.6/site-packages/seaborn/matrix.py in _determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     196                 vmin = np.nanpercentile(calc_data, 2)
#     197             else:
# --> 198                 vmin = np.nanmin(calc_data)
#     199         if vmax is None:
#     200             if robust:
#
# <__array_function__ internals> in nanmin(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/nanfunctions.py in nanmin(a, axis, out, keepdims)
#     317         # Fast, but not safe for subclasses of ndarray, or object arrays,
#     318         # which do not implement isnan (gh-9009), or fmin correctly (gh-8975)
# --> 319         res = np.fmin.reduce(a, axis=axis, out=out, **kwargs)
#     320         if np.isnan(res).any():
#     321             warnings.warn("All-NaN slice encountered", RuntimeWarning,
#
# ValueError: zero-size array to reduction operation fmin which has no identity

# %%
withdraw.head()
# Out:
#                                    type  \
# date
# 1970-01-01 00:00:01.606837339  withdraw
# 1970-01-01 00:00:01.606840529  withdraw
# 1970-01-01 00:00:01.606841476  withdraw
# 1970-01-01 00:00:01.606913119  withdraw
# 1970-01-01 00:00:01.606917505  withdraw
#
#                                                                      user  \
# date
# 1970-01-01 00:00:01.606837339  0xdcd33426ba191383f1c9b431a342498fdac73488
# 1970-01-01 00:00:01.606840529  0xdcd33426ba191383f1c9b431a342498fdac73488
# 1970-01-01 00:00:01.606841476  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 1970-01-01 00:00:01.606913119  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 1970-01-01 00:00:01.606917505  0xff06ed0e20638f1299832b4141bc3adcc82f6207
#
#                                          userAlias  \
# date
# 1970-01-01 00:00:01.606837339  Madison Lira-Chacon
# 1970-01-01 00:00:01.606840529  Madison Lira-Chacon
# 1970-01-01 00:00:01.606841476        Rocky Kuebler
# 1970-01-01 00:00:01.606913119        Rocky Kuebler
# 1970-01-01 00:00:01.606917505      Mariah Guerrero
#
#                                                                onBehalfOf  \
# date
# 1970-01-01 00:00:01.606837339  0xdcd33426ba191383f1c9b431a342498fdac73488
# 1970-01-01 00:00:01.606840529  0xdcd33426ba191383f1c9b431a342498fdac73488
# 1970-01-01 00:00:01.606841476  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 1970-01-01 00:00:01.606913119  0xbd723fc4f1d737dcfc48a07fe7336766d34cad5f
# 1970-01-01 00:00:01.606917505  0xff06ed0e20638f1299832b4141bc3adcc82f6207
#
#                                    onBehalfOfAlias  \
# date
# 1970-01-01 00:00:01.606837339  Madison Lira-Chacon
# 1970-01-01 00:00:01.606840529  Madison Lira-Chacon
# 1970-01-01 00:00:01.606841476        Rocky Kuebler
# 1970-01-01 00:00:01.606913119        Rocky Kuebler
# 1970-01-01 00:00:01.606917505      Mariah Guerrero
#
#                                                                      pool  \
# date
# 1970-01-01 00:00:01.606837339  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606840529  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606841476  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606913119  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606917505  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
#
#                               reserve    amount  amountUSD  amountETH  \
# date
# 1970-01-01 00:00:01.606837339    WETH  0.001000   0.467980   0.001000
# 1970-01-01 00:00:01.606840529    WETH  0.001000   0.467980   0.001000
# 1970-01-01 00:00:01.606841476     DAI  1.000000   1.001646   0.002140
# 1970-01-01 00:00:01.606913119     MKR  0.001000   0.514310   0.001099
# 1970-01-01 00:00:01.606917505    LINK  0.073858   0.942547   0.002014
#
#                                priceInUsd version deployment
# date
# 1970-01-01 00:00:01.606837339  467.980000      V2    Mainnet
# 1970-01-01 00:00:01.606840529  467.980000      V2    Mainnet
# 1970-01-01 00:00:01.606841476    1.001646      V2    Mainnet
# 1970-01-01 00:00:01.606913119  514.310020      V2    Mainnet
# 1970-01-01 00:00:01.606917505   12.761559      V2    Mainnet

# %%
corr = withdraw.corr()
sns.heatmap(corr, annot=True, ax=plt.subplots(figsize=(20, 10))[1])
plt.title('Correlation Heatmap')
plt.show()

# %%
repay.head()
# Out:
#                                 type  \
# date
# 1970-01-01 00:00:01.606905894  repay
# 1970-01-01 00:00:01.606916105  repay
# 1970-01-01 00:00:01.606917505  repay
# 1970-01-01 00:00:01.606927258  repay
# 1970-01-01 00:00:01.606928950  repay
#
#                                                                      user  \
# date
# 1970-01-01 00:00:01.606905894  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1970-01-01 00:00:01.606916105  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
# 1970-01-01 00:00:01.606917505  0x21d05071ca08593e13cd3afd0b4869537e015c92
# 1970-01-01 00:00:01.606927258  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1970-01-01 00:00:01.606928950  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
#
#                                            userAlias  \
# date
# 1970-01-01 00:00:01.606905894            Stephon Wal
# 1970-01-01 00:00:01.606916105         Jalen Mitchell
# 1970-01-01 00:00:01.606917505  Odaly Chihuahua-Tovar
# 1970-01-01 00:00:01.606927258            Stephon Wal
# 1970-01-01 00:00:01.606928950            Stephon Wal
#
#                                                                onBehalfOf  \
# date
# 1970-01-01 00:00:01.606905894  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1970-01-01 00:00:01.606916105  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
# 1970-01-01 00:00:01.606917505  0xff06ed0e20638f1299832b4141bc3adcc82f6207
# 1970-01-01 00:00:01.606927258  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1970-01-01 00:00:01.606928950  0xdcd33426ba191383f1c9b431a342498fdac73488
#
#                                    onBehalfOfAlias  \
# date
# 1970-01-01 00:00:01.606905894          Stephon Wal
# 1970-01-01 00:00:01.606916105       Jalen Mitchell
# 1970-01-01 00:00:01.606917505      Mariah Guerrero
# 1970-01-01 00:00:01.606927258          Stephon Wal
# 1970-01-01 00:00:01.606928950  Madison Lira-Chacon
#
#                                                                      pool  \
# date
# 1970-01-01 00:00:01.606905894  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606916105  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606917505  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606927258  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606928950  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
#
#                               reserve    amount  amountUSD  amountETH  \
# date
# 1970-01-01 00:00:01.606905894    LINK  1.000000  12.761559   0.027269
# 1970-01-01 00:00:01.606916105     DAI  1.000000   1.001646   0.002140
# 1970-01-01 00:00:01.606917505     DAI  1.000002   1.001648   0.002140
# 1970-01-01 00:00:01.606927258     YFI  0.000100   2.032905   0.004344
# 1970-01-01 00:00:01.606928950    WETH  0.100000  46.798135   0.100000
#
#                                  priceInUsd version deployment
# date
# 1970-01-01 00:00:01.606905894     12.761559      V2    Mainnet
# 1970-01-01 00:00:01.606916105      1.001646      V2    Mainnet
# 1970-01-01 00:00:01.606917505      1.001646      V2    Mainnet
# 1970-01-01 00:00:01.606927258  20329.051200      V2    Mainnet
# 1970-01-01 00:00:01.606928950    467.980000      V2    Mainnet

# %%
corr = repay.corr()
sns.heatmap(corr, annot=True, ax=plt.subplots(figsize=(20, 10))[1])
plt.title('Correlation Heatmap')
plt.show()

# %%
swap.head()
# Out:
#                                type  \
# date
# 1970-01-01 00:00:01.606925645  swap
# 1970-01-01 00:00:01.606951364  swap
# 1970-01-01 00:00:01.607000640  swap
# 1970-01-01 00:00:01.607003188  swap
# 1970-01-01 00:00:01.607003431  swap
#
#                                                                      user  \
# date
# 1970-01-01 00:00:01.606925645  0xdad4c11e8cc6a5c37808d3b31b3b284809f702d1
# 1970-01-01 00:00:01.606951364  0x39d637737cc76c5849a52c7d3b872a1eb22aa71c
# 1970-01-01 00:00:01.607000640  0x9ccf93089cb14f94baeb8822f8ceffd91bd71649
# 1970-01-01 00:00:01.607003188  0x0a80c3c540eef99811f4579fa7b1a0617294e06f
# 1970-01-01 00:00:01.607003431  0x0a80c3c540eef99811f4579fa7b1a0617294e06f
#
#                                      userAlias  \
# date
# 1970-01-01 00:00:01.606925645   Jalen Mitchell
# 1970-01-01 00:00:01.606951364      Stephon Wal
# 1970-01-01 00:00:01.607000640   Dallie Russell
# 1970-01-01 00:00:01.607003188  Bobby Shenefelt
# 1970-01-01 00:00:01.607003431  Bobby Shenefelt
#
#                                                                      pool  \
# date
# 1970-01-01 00:00:01.606925645  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606951364  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.607000640  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.607003188  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.607003431  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
#
#                               reserve borrowRateModeTo borrowRateModeFrom  \
# date
# 1970-01-01 00:00:01.606925645     DAI           Stable           Variable
# 1970-01-01 00:00:01.606951364     REN           Stable           Variable
# 1970-01-01 00:00:01.607000640     UNI         Variable             Stable
# 1970-01-01 00:00:01.607003188     ZRX         Variable             Stable
# 1970-01-01 00:00:01.607003431     ZRX           Stable           Variable
#
#                                stableBorrowRate  variableBorrowRate version  \
# date
# 1970-01-01 00:00:01.606925645          5.666667            3.333335      V2
# 1970-01-01 00:00:01.606951364          8.889100            6.222370      V2
# 1970-01-01 00:00:01.607000640          3.030825            1.767982      V2
# 1970-01-01 00:00:01.607003188         61.502194           55.502194      V2
# 1970-01-01 00:00:01.607003431         61.502774           55.502774      V2
#
#                               deployment
# date
# 1970-01-01 00:00:01.606925645    Mainnet
# 1970-01-01 00:00:01.606951364    Mainnet
# 1970-01-01 00:00:01.607000640    Mainnet
# 1970-01-01 00:00:01.607003188    Mainnet
# 1970-01-01 00:00:01.607003431    Mainnet

# %%
corr = swap.corr()
sns.heatmap(corr, annot=True, ax=plt.subplots(figsize=(20, 10))[1])
plt.title('Correlation Heatmap')
plt.show()

# %%
flashLoan.head()
# Out:
#                                     type  \
# date
# 1970-01-01 00:00:01.606939195  flashLoan
# 1970-01-01 00:00:01.606939515  flashLoan
# 1970-01-01 00:00:01.606941841  flashLoan
# 1970-01-01 00:00:01.607000090  flashLoan
# 1970-01-01 00:00:01.607005771  flashLoan
#
#                                                                      pool  \
# date
# 1970-01-01 00:00:01.606939195  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606939515  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.606941841  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.607000090  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
# 1970-01-01 00:00:01.607005771  0xb53c1a33016b2dc2ff3653530bff1848a515c8c5
#
#                               reserve        amount  \
# date
# 1970-01-01 00:00:01.606939195    USDC  9.991000e+06
# 1970-01-01 00:00:01.606939515    USDC  9.991000e+06
# 1970-01-01 00:00:01.606941841    USDC  9.991000e+07
# 1970-01-01 00:00:01.607000090     DAI  4.002141e+18
# 1970-01-01 00:00:01.607005771     DAI  9.991000e+20
#
#                                                                    target  \
# date
# 1970-01-01 00:00:01.606939195  0x6731b2228ef5294fc8995052f596d7c19b177de8
# 1970-01-01 00:00:01.606939515  0x6731b2228ef5294fc8995052f596d7c19b177de8
# 1970-01-01 00:00:01.606941841  0x6731b2228ef5294fc8995052f596d7c19b177de8
# 1970-01-01 00:00:01.607000090  0x6731b2228ef5294fc8995052f596d7c19b177de8
# 1970-01-01 00:00:01.607005771  0x73317bccdd6186b705c07f8306d5121011f84698
#
#                                    totalFee version deployment
# date
# 1970-01-01 00:00:01.606939195  8.991000e+03      V2    Mainnet
# 1970-01-01 00:00:01.606939515  8.991000e+03      V2    Mainnet
# 1970-01-01 00:00:01.606941841  8.991900e+04      V2    Mainnet
# 1970-01-01 00:00:01.607000090  3.601927e+15      V2    Mainnet
# 1970-01-01 00:00:01.607005771  8.991900e+17      V2    Mainnet

# %%
corr = flashLoan.corr()
sns.heatmap(corr, annot=True, ax=plt.subplots(figsize=(20, 10))[1])
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Below we will attempt to use tensorflow to create an RNN and use LSTM for time-series analysis. We will attempt to create a model that will effectively predict transaction rates by each type.

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
borrow = borrow.head(10000)
# Separate features and target variables (you can choose based on your prediction needs)
features = borrow.drop('amountUSD', axis=1)  # Features to predict amountUSD
target = borrow['amountUSD']

# %%
# Preprocess categorical features with One-Hot Encoding
categorical_features = ['userAlias', 'pool', 'reserve']
encoder = OneHotEncoder(sparse=False)

# %%
encoded_features = encoder.fit_transform(features[categorical_features])

# %%
# Combine numerical features (after normalization/scaling if needed) and encoded categorical features
processed_features = np.concatenate([features.drop(categorical_features, axis=1), encoded_features], axis=1)

# Define hyperparameters (experiment with these values)
embedding_dim = 16  # Experiment with different values
lstm_units = 32  # Experiment with different values
epochs = 10  # Experiment with different values
batch_size = 64  # Experiment with different values

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.24.2

# %% [markdown]
# Need to see if embedding dimensions can be calculated to use One Hot encoding for the model preparation

# %% [markdown]
# Some of the tensorflow and other packages must be updated in the IDEA cluster.

# %%
# encoded_features = encoder.fit_transform(features[categorical_features])
# categorical_feature_names = encoder.get_feature_names_out()  # Get encoded feature names
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-c68211fac369> in <module>
#       1 encoded_features = encoder.fit_transform(features[categorical_features])
# ----> 2 categorical_feature_names = encoder.get_feature_names_out()  # Get encoded feature names
#
# AttributeError: 'OneHotEncoder' object has no attribute 'get_feature_names_out'

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(processed_features, target, test_size=0.2, random_state=42)

# Define the model
model = keras.Sequential()

# Embedding layer for categorical features (adjust input_dim based on one-hot encoded vocabulary size)
model.add(keras.layers.Embedding(input_dim=encoder.get_feature_names_out().shape[0], output_dim=embedding_dim, input_length=processed_features.shape[1]))

# LSTM layers
model.add(keras.layers.LSTM(units=lstm_units, return_sequences=True))
model.add(keras.layers.LSTM(units=lstm_units))

# Output layer for predicting amountUSD (adjust based on your target variable)
model.add(keras.layers.Dense(units=1, activation='linear'))

# Compile the model
model.compile(loss='mse', optimizer='adam')

# Train the model
model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))

# Make predictions on testing set
y_pred = model.predict(X_test)

# Evaluate model performance (e.g., calculate mean squared error)
mse = tf.keras.losses.MeanSquaredError()
loss = mse(y_test, y_pred)
print(f"Mean Squared Error on Testing Set: {loss.numpy()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-4b9bbd05357d> in <module>
#       1 # Split data into training and testing sets
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(processed_features, target, test_size=0.2, random_state=42)
#       3
#       4 # Define the model
#       5 model = keras.Sequential()
#
# NameError: name 'train_test_split' is not defined
